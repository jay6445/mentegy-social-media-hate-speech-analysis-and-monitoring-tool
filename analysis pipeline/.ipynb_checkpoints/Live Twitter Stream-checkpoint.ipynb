# %%
import requests
import os
import json
import pandas as pd
from pandas import json_normalize

# %%
# %env BEARER_TOKEN= AAAAAAAAAAAAAAAAAAAAAPKsMQEAAAAAzz%2BOfrKTbyWOASJmxt8BAuIGnx0%3Dikjh5IxQK1hTKtrHAvr4sVJxkCKPjOnzUkheU4IK9XCvwOtblS
# Out:
# env: BEARER_TOKEN=AAAAAAAAAAAAAAAAAAAAAPKsMQEAAAAAzz%2BOfrKTbyWOASJmxt8BAuIGnx0%3Dikjh5IxQK1hTKtrHAvr4sVJxkCKPjOnzUkheU4IK9XCvwOtblS

# %%
def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"

# %%
# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

# %%
def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

# %%
def set_rules(headers, delete, bearer_token):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "dog has:images", "tag": "dog pictures"},
        {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

# %%
def get_stream(headers, set, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
def main():
    bearer_token = os.environ.get("BEARER_TOKEN")
    headers = create_headers(bearer_token)
    rules = get_rules(headers, bearer_token)
    delete = delete_all_rules(headers, bearer_token, rules)
    set = set_rules(headers, delete, bearer_token)
    get_stream(headers, set, bearer_token)

# %%
if __name__ == "__main__":
    main()
# Out:
# {"data": [{"id": "1396141082447077376", "value": "cat has:images -grumpy", "tag": "cat pictures"}, {"id": "1396141082447077377", "value": "dog has:images", "tag": "dog pictures"}], "meta": {"sent": "2021-05-22T16:36:48.638Z"}}
# {"meta": {"sent": "2021-05-22T16:36:50.031Z", "summary": {"deleted": 2, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1396143022711222297"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1396143022711222296"}], "meta": {"sent": "2021-05-22T16:36:51.301Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1396142986606649347",
#         "text": "My dog could've wrote a more believable article. Imagine wasting your time doing this bc you're so mad about another bands success its funny to me https://t.co/YA5NJLWqSx"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1

#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143139736330242",
#         "text": "I see things my cat mom cannot! Unnerving for her sometimes.\nHi, Wanda! What do you see?\n@HalifaxAuthor https://t.co/lAP5FC2BhC"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143142542401536",
#         "text": "\u0644\u0648\u06a9\u06cc\u0634\u0646:\nDog's Bay\n\u062f\u0645 \u0633\u0627\u062d\u0644 \u0634\u0631\u0642\u06cc \u0627\u0642\u06cc\u0627\u0646\u0648\u0633 \u0627\u0637\u0644\u0633\n\u0627\u0648\u0646\u062c\u0627\u06cc\u06cc \u06a9\u0647 \u0627\u0631\u0648\u067e\u0627 \u062a\u0645\u0648\u0645 \u0645\u06cc\u0634\u0647 https://t.co/7F3xIJWpbN"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143143888719877",
#         "text": "RT @AmbedkarCaravan: When a few years ago Periyar followers had put Janeu on a picture of a pig to protest against Brahminism, there was a\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143147810390024",
#         "text": "RT @shooley_art: It starts off with one cat during quarantine... https://t.co/ynr8b899fC"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143150356307971",
#         "text": "@DouglasWArcher https://t.co/7UcAcoqV2t"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143154357673984",
#         "text": "RT @ananavarro: Met @RepValDemings yesterday. What an inspiring story. She grew-up poor, one of seven children of a maid and a janitor. Ser\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143154777182208",
#         "text": "@tedcruz Brian Williams had 1 lapse in judgement. What's your excuse?   Sucking up 2 the psycho who WAS in WH after he called Heidi a Dog/ accused your dictator dad of Kennedy assassination. Or the way U abandoned us in Houston &amp; left a small \ud83d\udc36  in freezing \ud83c\udfda.   Raphael is Despicable. https://t.co/C7DLQqYEku"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143157486645253",
#         "text": "RT @1st_Army_Area: \u0e23\u0e32\u0e0a\u0e27\u0e34\u0e17\u0e22\u0e32\u0e25\u0e31\u0e22\u0e08\u0e38\u0e2c\u0e32\u0e20\u0e23\u0e13\u0e4c \u0e22\u0e49\u0e32\u0e22\u0e28\u0e39\u0e19\u0e22\u0e4c\u0e09\u0e35\u0e14\u0e27\u0e31\u0e04\u0e0b\u0e35\u0e19 \u0e44\u0e1b\u0e17\u0e35\u0e48 CAT Convention Hall \u0e41\u0e08\u0e49\u0e07\u0e27\u0e31\u0e12\u0e19\u0e30 \u0e15\u0e31\u0e49\u0e07\u0e41\u0e15\u0e48\u0e27\u0e31\u0e19\u0e08\u0e31\u0e19\u0e17\u0e23\u0e4c\u0e17\u0e35\u0e48 24 \u0e1e.\u0e04.64 \u0e1a\u0e23\u0e34\u0e01\u0e32\u0e23\u0e2a\u0e33\u0e2b\u0e23\u0e31\u0e1a\u0e1c\u0e39\u0e49\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143158065565696",
#         "text": "RT @ArturooArtur: Nawet piese\u0142 posmutnia\u0142 jak dowiedzia\u0142 si\u0119, \u017ce jego dog car si\u0119 zepsu\u0142\ud83d\ude48 https://t.co/ls0AMUVNej"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143158270984195",
#         "text": "RT @catsdotexe: \"woman cuts the hem of her kimono to not wake her cat\" https://t.co/TQp5c0kbLV"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143159953006595",
#         "text": "RT @AeroViro: Breakfast with my friend Eule since she\u2019s staying with me for a few days.\n\nAnd obviously my needy cat Rascal https://t.co/rBb\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143160267509762",
#         "text": "RT @POPULARPUPPlES: Me when, Every time I see a street dog: https://t.co/Jpu9ec1yEW"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222296,
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396143162326925323",
#         "text": "RT @catsnkittys: Time for a really cute kitten\u2026 \n\n[See ALL our best cat Pix here -\u00a0https://t.co/IGSN4Lw3WT] https://t.co/ckNz2d55tX"
#     },
#     "matching_rules": [
#         {
#             "id": 1396143022711222297,
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1396