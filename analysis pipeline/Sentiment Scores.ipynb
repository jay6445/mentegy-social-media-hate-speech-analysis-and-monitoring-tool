# %%
import sys
# !{sys.executable} -m pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 7.8 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.8/site-packages (from vaderSentiment) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2020.6.20)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import sys
# !{sys.executable} -m pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.18.0-py2.py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.2 MB/s eta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ### We import vader sentiment library and create an object for polarity analyzer

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# ### We import the twitter library for scraping the tweets

# %%
import twitter
CONSUMER_KEY = 'Jp60fiXqcrPERr99huKZHo0j2'
CONSUMER_SECRET = 'FshigJziR49mXK4xooijtTTHb5JsciNuxJhoThPWwYGzJLzCrj'
OAUTH_TOKEN = '398887985-YNwM0zv5Jviy5dXIMgdyNah17G4UpSlUrTXBgoSa'
OAUTH_TOKEN_SECRET = 'sS8QkFoOx0pJPJsAsL6ttmDIt90t2rBwpfb8g8nTNGUce'
auth =  twitter.oauth.OAuth(OAUTH_TOKEN,OAUTH_TOKEN_SECRET,CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

# %%
# We scraped 200 tweets

# %%
count = 200
query = ["asian","asians"]
tweets = twitter_api.search.tweets(q=query, count=count, 
   lang='en',tweet_mode="extended")

# %%
tweets
# Out:
# {'statuses': [{'created_at': 'Tue Apr 06 14:54:47 +0000 2021',
#    'id': 1379447501531529217,
#    'id_str': '1379447501531529217',
#    'full_text': 'RT @badvibesdni: finally asian racism is being talked about again \nhere are some things you can do to stop (normalized) asian racism \nthese…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'badvibesdni',
#       'name': 'oli rt pinned!',
#       'id': 1268764277835350019,
#       'id_str': '1268764277835350019',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1340689497575534598,
#     'id_str': '1340689497575534598',
#     'name': 'ًemrys',
#     'screen_name': 'DwtzGnf',
#     'location': '',
#     'description': 'Gnf ^__^',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 679,
#     'friends_count': 1302,
#     'listed_count': 9,
#     'created_at': 'Sun Dec 20 16:04:31 +0000 2020',
#     'favourites_count': 21222,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 13167,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1378921231039279107/1dt7hVa-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1378921231039279107/1dt7hVa-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1340689497575534598/1617633211',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 06:13:49 +0000 2021',
#     'id': 1379316394232188929,
#     'id_str': '1379316394232188929',
#     'full_text': 'finally asian racism is being talked about again \nhere are some things you can do to stop (normalized) asian racism \nthese are personal experiences btw and other asians feel free to add on theres a lot',
#     'truncated': False,
#     'display_text_range': [0, 201],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1268764277835350019,
#      'id_str': '1268764277835350019',
#      'name': 'oli rt pinned!',
#      'screen_name': 'badvibesdni',
#      'location': 'they/xe/he  ',
#      'description': 'feraltwt ☆ bootwt ☆ sleepytwt',
#      'url': 'https://t.co/7kySAaLp7q',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/7kySAaLp7q',
#          'expanded_url': 'https://www.youtube.com/watch?v=YddwkMJG1Jo',
#          'display_url': 'youtube.com/watch?v=YddwkM…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2253,
#      'friends_count': 2250,
#      'listed_count': 20,
#      'created_at': 'Fri Jun 05 04:39:17 +0000 2020',
#      'favourites_count': 19572,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5455,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1374431709853184001/X4uykY6c_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1374431709853184001/X4uykY6c_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1268764277835350019/1615478429',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 80,
#     'favorite_count': 103,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 80,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 14:54:24 +0000 2021',
#    'id': 1379447403820900361,
#    'id_str': '1379447403820900361',
#    'full_text': 'RT @VABVOX: Pretty sure VP Harris is the most prominent Asian/AAPI American. And that more people are familiar with Sen. Tammy Duckworth th…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'VABVOX',
#       'name': 'Victoria Brownworth',
#       'id': 138168339,
#       'id_str': '138168339',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25624686,
#     'id_str': '25624686',
#     'name': 'Wendy Peffercorn',
#     'screen_name': 'Evie224',
#     'location': '└A ✈ Pdx [C-137]',
#     'description': 'She/Her | I don’t want to live on this planet anymore | Void where prohibited | If you are my employer, please look away | 💚MJM | 🇸🇻🇬🇹',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 283,
#     'friends_count': 851,
#     'listed_count': 5,
#     'created_at': 'Sat Mar 21 02:31:01 +0000 2009',
#     'favourites_count': 17657,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 30286,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1378578312264474625/_HKTPO9c_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1378578312264474625/_HKTPO9c_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25624686/1617491135',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 13:23:52 +0000 2021',
#     'id': 1379424621510983681,
#     'id_str': '1379424621510983681',
#     'full_text': "Pretty sure VP Harris is the most prominent Asian/AAPI American. And that more people are familiar with Sen. Tammy Duckworth than Andrew Yang. There are also other Asians in Congress--Mazie Hirono, Ted Lieu, Judy Chu-- who'd feel slighted by this unnecessary characterization. https://t.co/fcibD53xPg",
#     'truncated': False,
#     'display_text_range': [0, 276],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fcibD53xPg',
#        'expanded_url': 'https://twitter.com/politico/status/1379193395202113538',
#        'display_url': 'twitter.com/politico/statu…',
#        'indices': [277, 300]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 138168339,
#      'id_str': '138168339',
#      'name': 'Victoria Brownworth',
#      'screen_name': 'VABVOX',
#      'location': 'Philly, natch',
#      'description': 'Award-winning investigative journo. Fmr @baltimoresun @PhillyDailyNews.\nWrites books. Real-life Socialist. #FightFor15 #M4A #BLM #GunControl 🏳️\u200d🌈 ♿  she/her',
#      'url': 'https://t.co/Cha2mx2RmX',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Cha2mx2RmX',
#          'expanded_url': 'http://www.victoriabrownworth.com',
#          'display_url': 'victoriabrownworth.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 105555,
#      'friends_count': 4028,
#      'listed_count': 1210,
#      'created_at': 'Wed Apr 28 20:29:42 +0000 2010',
#      'favourites_count': 379451,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 434404,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1198816383414521857/6AsbYoYg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1198816383414521857/6AsbYoYg_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138168339/1375567628',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1379193395202113538,
#     'quoted_status_id_str': '1379193395202113538',
#     'quoted_status': {'created_at': 'Mon Apr 05 22:05:04 +0000 2021',
#      'id': 1379193395202113538,
#      'id_str': '1379193395202113538',
#      'full_text': 'Andrew Yang is the most prominent Asian American political figure in the country. We asked why he’d never really discussed the issue of AAPI identity in depth before. \n\n“Mostly,” he said, “because no one asked.” https://t.co/ZBbyGu9ZlA',
#      'truncated': False,
#      'display_text_range': [0, 235],
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/ZBbyGu9ZlA',
#         'expanded_url': 'https://www.politico.com/news/magazine/2021/04/04/andrew-yangs-asian-american-superpower-479011',
#         'display_url': 'politico.com/news/magazine/…',
#         'indices': [212, 235]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 9300262,
#       'id_str': '9300262',
#       'name': 'POLITICO',
#       'screen_name': 'politico',
#       'location': 'Washington, D.C.',
#       'description': 'Nobody knows politics like POLITICO. Got a news tip for us? \n👉 https://t.co/fp9nugJuND',
#       'url': 'https://t.co/PPMyQsPlIg',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/PPMyQsPlIg',
#           'expanded_url': 'http://politico.com',
#           'display_url': 'politico.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/fp9nugJuND',
#           'expanded_url': 'https://politi.co/2LcOtt5',
#           'display_url': 'politi.co/2LcOtt5',
#           'indices': [63, 86]}]}},
#       'protected': False,
#       'followers_count': 4507368,
#       'friends_count': 1561,
#       'listed_count': 42671,
#       'created_at': 'Mon Oct 08 00:29:38 +0000 2007',
#       'favourites_count': 92,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 350891,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'E6E6E6',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9300262/1479760803',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'regular'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 194,
#      'favorite_count': 838,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 125,
#     'favorite_count': 589,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1379193395202113538,
#    'quoted_status_id_str': '1379193395202113538',
#    'retweet_count': 125,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 14:54:18 +0000 2021',
#    'id': 1379447377497497600,
#    'id_str': '1379447377497497600',
#    'full_text': 'RT @VABVOX: Pretty sure VP Harris is the most prominent Asian/AAPI American. And that more people are familiar with Sen. Tammy Duckworth th…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'VABVOX',
#       'name': 'Victoria Brownworth',
#       'id': 138168339,
#       'id_str': '138168339',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3164467356,
#     'id_str': '3164467356',
#     'name': 'Nic HAS HAD ENOUGH!',
#     'screen_name': 'NixJustice',
#     'location': 'Planet Earth',
#     'description': '💍@_Justicism_ ❤️ Biden won. Fuck your feelings and wear a goddamn mask #fuckMAGA #fuckTrump #impeachnow',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 162,
#     'friends_count': 997,
#     'listed_count': 8,
#     'created_at': 'Sun Apr 19 22:25:39 +0000 2015',
#     'favourites_count': 22614,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4598,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1270128041956478977/D9FEDYPC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270128041956478977/D9FEDYPC_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3164467356/1610224387',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 13:23:52 +0000 2021',
#     'id': 1379424621510983681,
#     'id_str': '1379424621510983681',
#     'full_text': "Pretty sure VP Harris is the most prominent Asian/AAPI American. And that more people are familiar with Sen. Tammy Duckworth than Andrew Yang. There are also other Asians in Congress--Mazie Hirono, Ted Lieu, Judy Chu-- who'd feel slighted by this unnecessary characterization. https://t.co/fcibD53xPg",
#     'truncated': False,
#     'display_text_range': [0, 276],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fcibD53xPg',
#        'expanded_url': 'https://twitter.com/politico/status/1379193395202113538',
#        'display_url': 'twitter.com/politico/statu…',
#        'indices': [277, 300]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 138168339,
#      'id_str': '138168339',
#      'name': 'Victoria Brownworth',
#      'screen_name': 'VABVOX',
#      'location': 'Philly, natch',
#      'description': 'Award-winning investigative journo. Fmr @baltimoresun @PhillyDailyNews.\nWrites books. Real-life Socialist. #FightFor15 #M4A #BLM #GunControl 🏳️\u200d🌈 ♿  she/her',
#      'url': 'https://t.co/Cha2mx2RmX',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Cha2mx2RmX',
#          'expanded_url': 'http://www.victoriabrownworth.com',
#          'display_url': 'victoriabrownworth.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 105555,
#      'friends_count': 4028,
#      'listed_count': 1210,
#      'created_at': 'Wed Apr 28 20:29:42 +0000 2010',
#      'favourites_count': 379451,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 434404,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1198816383414521857/6AsbYoYg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1198816383414521857/6AsbYoYg_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138168339/1375567628',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1379193395202113538,
#     'quoted_status_id_str': '1379193395202113538',
#     'quoted_status': {'created_at': 'Mon Apr 05 22:05:04 +0000 2021',
#      'id': 1379193395202113538,
#      'id_str': '1379193395202113538',
#      'full_text': 'Andrew Yang is the most prominent Asian American political figure in the country. We asked why he’d never really discussed the issue of AAPI identity in depth before. \n\n“Mostly,” he said, “because no one asked.” https://t.co/ZBbyGu9ZlA',
#      'truncated': False,
#      'display_text_range': [0, 235],
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/ZBbyGu9ZlA',
#         'expanded_url': 'https://www.politico.com/news/magazine/2021/04/04/andrew-yangs-asian-american-superpower-479011',
#         'display_url': 'politico.com/news/magazine/…',
#         'indices': [212, 235]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 9300262,
#       'id_str': '9300262',
#       'name': 'POLITICO',
#       'screen_name': 'politico',
#       'location': 'Washington, D.C.',
#       'description': 'Nobody knows politics like POLITICO. Got a news tip for us? \n👉 https://t.co/fp9nugJuND',
#       'url': 'https://t.co/PPMyQsPlIg',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/PPMyQsPlIg',
#           'expanded_url': 'http://politico.com',
#           'display_url': 'politico.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/fp9nugJuND',
#           'expanded_url': 'https://politi.co/2LcOtt5',
#           'display_url': 'politi.co/2LcOtt5',
#           'indices': [63, 86]}]}},
#       'protected': False,
#       'followers_count': 4507368,
#       'friends_count': 1561,
#       'listed_count': 42671,
#       'created_at': 'Mon Oct 08 00:29:38 +0000 2007',
#       'favourites_count': 92,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 350891,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'E6E6E6',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9300262/1479760803',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'regular'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 194,
#      'favorite_count': 838,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 125,
#     'favorite_count': 589,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1379193395202113538,
#    'quoted_status_id_str': '1379193395202113538',
#    'retweet_count': 125,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 14:54:16 +0000 2021',
#    'id': 1379447368844730373,
#    'id_str': '1379447368844730373',
#    'full_text': '@MelanieForEdu @RethinkSchools You mean how you treated Asians as “white adjacent” and abandoned the merit test to get into TJ?  Right @AsraNomani ? What about your political party getting rid of the only Asian on the school board, Mr. Moon in a primary?',
#    'truncated': False,
#    'display_text_range': [31, 254],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MelanieForEdu',
#       'name': '@MelanieForEdu',
#       'id': 361221556,
#       'id_str': '361221556',
#       'indices': [0, 14]},
#      {'screen_name': 'RethinkSchools',
#       'name': 'Rethinking Schools',
#       'id': 161580500,
#       'id_str': '161580500',
#       'indices': [15, 30]},
#      {'screen_name': 'AsraNomani',
#       'name': 'Asra Q. Nomani',
#       'id': 45617221,
#       'id_str': '45617221',
#       'indices': [135, 146]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1379176569244094465,
#    'in_reply_to_status_id_str': '1379176569244094465',
#    'in_reply_to_user_id': 361221556,
#    'in_reply_to_user_id_str': '361221556',
#    'in_reply_to_screen_name': 'MelanieForEdu',
#    'user': {'id': 33720578,
#     'id_str': '33720578',
#     'name': 'Jo-Anne Sears',
#     'screen_name': 'JoAnnePSears',
#     'location': 'Reading The Economist',
#     'description': 'Children’s Advocate. Space Nerd. Free Thinker. Slayer of Hypocrisy. Laura Jane Cohen’s Conscience 🦄🌈.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 361,
#     'friends_count': 971,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 20 23:47:24 +0000 2009',
#     'favourites_count': 5450,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2679,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FF6699',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1364006148/Cartoon_Me__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1364006148/Cartoon_Me__normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33720578/1608085291',
#     'profile_link_color': 'B40B43',
#     'profile_sidebar_border_color': 'CC3366',
#     'profile_sidebar_fill_color': 'E5507E',
#     'profile_text_color': '362720',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 14:54:15 +0000 2021',
#    'id': 1379447365543755777,
#    'id_str': '1379447365543755777',
#    'full_text': 'RT @VABVOX: Pretty sure VP Harris is the most prominent Asian/AAPI American. And that more people are familiar with Sen. Tammy Duckworth th…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'VABVOX',
#       'name': 'Victoria Brownworth',
#       'id': 138168339,
#       'id_str': '138168339',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 14740408,
#     'id_str': '14740408',
#     'name': 'Judy',
#     'screen_name': 'HeyJude408',
#     'location': 'Left Coast',
#     'description': 'Humanity 1st, compassion is without borders, 808 & 408 roots, traveler, trekker, Kyoji’s bachan, repulsed by MAGAts, turned off by opportunists of all stripes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3081,
#     'friends_count': 3363,
#     'listed_count': 317,
#     'created_at': 'Mon May 12 04:27:41 +0000 2008',
#     'favourites_count': 9371,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 54188,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '381B07',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1245561540842909696/yzFtygN0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1245561540842909696/yzFtygN0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14740408/1440992371',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'C5DBCA',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 13:23:52 +0000 2021',
#     'id': 1379424621510983681,
#     'id_str': '1379424621510983681',
#     'full_text': "Pretty sure VP Harris is the most prominent Asian/AAPI American. And that more people are familiar with Sen. Tammy Duckworth than Andrew Yang. There are also other Asians in Congress--Mazie Hirono, Ted Lieu, Judy Chu-- who'd feel slighted by this unnecessary characterization. https://t.co/fcibD53xPg",
#     'truncated': False,
#     'display_text_range': [0, 276],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fcibD53xPg',
#        'expanded_url': 'https://twitter.com/politico/status/1379193395202113538',
#        'display_url': 'twitter.com/politico/statu…',
#        'indices': [277, 300]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 138168339,
#      'id_str': '138168339',
#      'name': 'Victoria Brownworth',
#      'screen_name': 'VABVOX',
#      'location': 'Philly, natch',
#      'description': 'Award-winning investigative journo. Fmr @baltimoresun @PhillyDailyNews.\nWrites books. Real-life Socialist. #FightFor15 #M4A #BLM #GunControl 🏳️\u200d🌈 ♿  she/her',
#      'url': 'https://t.co/Cha2mx2RmX',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Cha2mx2RmX',
#          'expanded_url': 'http://www.victoriabrownworth.com',
#          'display_url': 'victoriabrownworth.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 105555,
#      'friends_count': 4028,
#      'listed_count': 1210,
#      'created_at': 'Wed Apr 28 20:29:42 +0000 2010',
#      'favourites_count': 379451,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 434404,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1198816383414521857/6AsbYoYg_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1198816383414521857/6AsbYoYg_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/138168339/1375567628',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1379193395202113538,
#     'quoted_status_id_str': '1379193395202113538',
#     'quoted_status': {'created_at': 'Mon Apr 05 22:05:04 +0000 2021',
#      'id': 1379193395202113538,
#      'id_str': '1379193395202113538',
#      'full_text': 'Andrew Yang is the most prominent Asian American political figure in the country. We asked why he’d never really discussed the issue of AAPI identity in depth before. \n\n“Mostly,” he said, “because no one asked.” https://t.co/ZBbyGu9ZlA',
#      'truncated': False,
#      'display_text_range': [0, 235],
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/ZBbyGu9ZlA',
#         'expanded_url': 'https://www.politico.com/news/magazine/2021/04/04/andrew-yangs-asian-american-superpower-479011',
#         'display_url': 'politico.com/news/magazine/…',
#         'indices': [212, 235]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 9300262,
#       'id_str': '9300262',
#       'name': 'POLITICO',
#       'screen_name': 'politico',
#       'location': 'Washington, D.C.',
#       'description': 'Nobody knows politics like POLITICO. Got a news tip for us? \n👉 https://t.co/fp9nugJuND',
#       'url': 'https://t.co/PPMyQsPlIg',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/PPMyQsPlIg',
#           'expanded_url': 'http://politico.com',
#           'display_url': 'politico.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/fp9nugJuND',
#           'expanded_url': 'https://politi.co/2LcOtt5',
#           'display_url': 'politi.co/2LcOtt5',
#           'indices': [63, 86]}]}},
#       'protected': False,
#       'followers_count': 4507368,
#       'friends_count': 1561,
#       'listed_count': 42671,
#       'created_at': 'Mon Oct 08 00:29:38 +0000 2007',
#       'favourites_count': 92,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 350891,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'E6E6E6',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9300262/1479760803',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'regular'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 194,
#      'favorite_count': 838,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 125,
#     'favorite_count': 589,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1379193395202113538,
#    'quoted_status_id_str': '1379193395202113538',
#    'retweet_count': 125,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 14:53:49 +0000 2021',
#    'id': 1379447254596091907,
#    'id_str': '1379447254596091907',
#    'full_text': 'RT @DevTrehan: BREAKING: Sikh brothers Bhups and Sunny Singh Gill to make EFL history when Bristol City host @NFFC on Saturday.\n\nPair will…',
#    'truncated': False,
#    'display_text_range': [0, 139],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DevTrehan',
#       'name': 'Dev Trehan',
#       'id': 747043795,
#       'id_str': '747043795',
#       'indices': [3, 13]},
#      {'screen_name': 'NFFC',
#       'name': 'Nottingham Forest FC 💙',
#       'id': 39754653,
#       'id_str': '39754653',
#       'indices': [109, 114]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1621600171,
#     'id_str': '1621600171',
#     'name': 'Tarun',
#     'screen_name': 'bains_tarun',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 295,
#     'friends_count': 291,
#     'listed_count': 1,
#     'created_at': 'Fri Jul 26 00:03:17 +0000 2013',
#     'favourites_count': 9640,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 9286,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1364621656136839170/MuMiQJzs_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1364621656136839170/MuMiQJzs_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1621600171/1616361776',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 12:49:30 +0000 2021',
#     'id': 1379415969416814596,
#     'id_str': '1379415969416814596',
#     'full_text': 'BREAKING: Sikh brothers Bhups and Sunny Singh Gill to make EFL history when Bristol City host @NFFC on Saturday.\n\nPair will be the first British South Asians to officiate the same Championship game, days before #Vaisakhi 👇\n\nhttps://t.co/XNDZF6TS7b #PunjabiRefsMakeHistory https://t.co/zywGpV9EAn',
#     'truncated': False,
#     'display_text_range': [0, 271],
#     'entities': {'hashtags': [{'text': 'Vaisakhi', 'indices': [211, 220]},
#       {'text': 'PunjabiRefsMakeHistory', 'indices': [248, 271]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'NFFC',
#        'name': 'Nottingham Forest FC 💙',
#        'id': 39754653,
#        'id_str': '39754653',
#        'indices': [94, 99]}],
#      'urls': [{'url': 'https://t.co/XNDZF6TS7b',
#        'expanded_url': 'https://www.skysports.com/football/news/11095/12266232/championship-history-to-be-made-by-british-south-asian-referees-bhups-and-sunny-singh-gill',
#        'display_url': 'skysports.com/football/news/…',
#        'indices': [224, 247]}],
#      'media': [{'id': 1379379673566752773,
#        'id_str': '1379379673566752773',
#        'indices': [272, 295],
#        'media_url': 'http://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'url': 'https://t.co/zywGpV9EAn',
#        'display_url': 'pic.twitter.com/zywGpV9EAn',
#        'expanded_url': 'https://twitter.com/DevTrehan/status/1379415969416814596/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1379379673566752773,
#        'id_str': '1379379673566752773',
#        'indices': [272, 295],
#        'media_url': 'http://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'url': 'https://t.co/zywGpV9EAn',
#        'display_url': 'pic.twitter.com/zywGpV9EAn',
#        'expanded_url': 'https://twitter.com/DevTrehan/status/1379415969416814596/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 747043795,
#      'id_str': '747043795',
#      'name': 'Dev Trehan',
#      'screen_name': 'DevTrehan',
#      'location': 'London - Liverpool - Las Vegas',
#      'description': 'Changing the landscape @SkySportsNews\nArchitect: #HiddenFigures Digital: #MyIcon\nCo-world record holder \nEx @talkSPORT @bbc5live @EasternEye \nAmbassador of Quan',
#      'url': 'http://t.co/lv9Lm1CFza',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/lv9Lm1CFza',
#          'expanded_url': 'http://www.facebook.com/devtrehan46',
#          'display_url': 'facebook.com/devtrehan46',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1965,
#      'friends_count': 2282,
#      'listed_count': 42,
#      'created_at': 'Thu Aug 09 11:16:58 +0000 2012',
#      'favourites_count': 2821,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10119,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915639503011926016/NmM-rRQF_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915639503011926016/NmM-rRQF_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/747043795/1507140037',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 53,
#     'favorite_count': 178,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 53,
#    'favorite_count': 0,
# ...
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2722124335,
#     'id_str': '2722124335',
#     'name': 'Omarosas Cracked Heels',
#     'screen_name': 'LucyLala80',
#     'location': 'California, USA',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 47,
#     'friends_count': 547,
#     'listed_count': 0,
#     'created_at': 'Sun Aug 10 17:29:47 +0000 2014',
#     'favourites_count': 49516,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7165,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1324394686614654977/an0QvUI8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1324394686614654977/an0QvUI8_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 14:30:16 +0000 2021',
#     'id': 1379441329873285120,
#     'id_str': '1379441329873285120',
#     'full_text': 'This tweet implies that female Asian American politicians cannot be “prominent,” given our current VP is AA. But beyond that, while I like some of Andrew Yang’s ideas, and representation matters, I will never forget when he told Asians to prove our Americanness. https://t.co/wSi8wjeO6V',
#     'truncated': False,
#     'display_text_range': [0, 262],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/wSi8wjeO6V',
#        'expanded_url': 'https://twitter.com/politico/status/1379193395202113538',
#        'display_url': 'twitter.com/politico/statu…',
#        'indices': [263, 286]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 872710897,
#      'id_str': '872710897',
#      'name': 'The Korean Vegan, Esq.',
#      'screen_name': 'thekoreanvegan',
#      'location': 'Chicago, IL',
#      'description': '@thekoreanvegan on TikTok. Unapologetic advocate of democracy and hater of racism in all forms. Opinions are my own and nothing I say constitutes legal advice.',
#      'url': 'https://t.co/CZZYM9670S',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/CZZYM9670S',
#          'expanded_url': 'http://thekoreanvegan.com',
#          'display_url': 'thekoreanvegan.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 43036,
#      'friends_count': 1049,
#      'listed_count': 170,
#      'created_at': 'Thu Oct 11 00:09:29 +0000 2012',
#      'favourites_count': 25510,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5127,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1331429279830335489/o4tvutvy_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1331429279830335489/o4tvutvy_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/872710897/1604503820',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1379193395202113538,
#     'quoted_status_id_str': '1379193395202113538',
#     'quoted_status': {'created_at': 'Mon Apr 05 22:05:04 +0000 2021',
#      'id': 1379193395202113538,
#      'id_str': '1379193395202113538',
#      'full_text': 'Andrew Yang is the most prominent Asian American political figure in the country. We asked why he’d never really discussed the issue of AAPI identity in depth before. \n\n“Mostly,” he said, “because no one asked.” https://t.co/ZBbyGu9ZlA',
#      'truncated': False,
#      'display_text_range': [0, 235],
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/ZBbyGu9ZlA',
#         'expanded_url': 'https://www.politico.com/news/magazine/2021/04/04/andrew-yangs-asian-american-superpower-479011',
#         'display_url': 'politico.com/news/magazine/…',
#         'indices': [212, 235]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 9300262,
#       'id_str': '9300262',
#       'name': 'POLITICO',
#       'screen_name': 'politico',
#       'location': 'Washington, D.C.',
#       'description': 'Nobody knows politics like POLITICO. Got a news tip for us? \n👉 https://t.co/fp9nugJuND',
#       'url': 'https://t.co/PPMyQsPlIg',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/PPMyQsPlIg',
#           'expanded_url': 'http://politico.com',
#           'display_url': 'politico.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/fp9nugJuND',
#           'expanded_url': 'https://politi.co/2LcOtt5',
#           'display_url': 'politi.co/2LcOtt5',
#           'indices': [63, 86]}]}},
#       'protected': False,
#       'followers_count': 4507368,
#       'friends_count': 1561,
#       'listed_count': 42671,
#       'created_at': 'Mon Oct 08 00:29:38 +0000 2007',
#       'favourites_count': 92,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': True,
#       'statuses_count': 350891,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'E6E6E6',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/677177503694237697/y6yTzWn6_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9300262/1479760803',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'regular'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 194,
#      'favorite_count': 840,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 17,
#     'favorite_count': 125,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1379193395202113538,
#    'quoted_status_id_str': '1379193395202113538',
#    'retweet_count': 17,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 14:37:49 +0000 2021',
#    'id': 1379443228458545164,
#    'id_str': '1379443228458545164',
#    'full_text': 'RT @GoAwayWithJae: "I never heard anyone use slurs against Asians..." -- non-Asian person\n\nThis is a common reply from people to downplay w…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GoAwayWithJae',
#       'name': 'Jae-Ha Kim 김재하',
#       'id': 222680234,
#       'id_str': '222680234',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1322558328359309313,
#     'id_str': '1322558328359309313',
#     'name': 'Freja',
#     'screen_name': 'FrejaIldri',
#     'location': 'Hampton Roads, VA',
#     'description': '💜 my kids, my -ships, my solo time, my traveling, my worktime, my playtime. Yeah, I’m 1 of the DOPE old people RM talks about.🔞 #raplinebias',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 87,
#     'friends_count': 196,
#     'listed_count': 0,
#     'created_at': 'Sat Oct 31 15:21:46 +0000 2020',
#     'favourites_count': 3025,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1873,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1350418005293998080/FoFpmcop_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1350418005293998080/FoFpmcop_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1322558328359309313/1614170073',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 13:49:52 +0000 2021',
#     'id': 1379431164058820615,
#     'id_str': '1379431164058820615',
#     'full_text': '"I never heard anyone use slurs against Asians..." -- non-Asian person\n\nThis is a common reply from people to downplay what\'s going on. Why would you hear it if you\'re not Asian? People don\'t target non-Asian people for anti-Asian hate.🤓\n\n#StopAsianHateCrimes #StopAAPIHate',
#     'truncated': False,
#     'display_text_range': [0, 273],
#     'entities': {'hashtags': [{'text': 'StopAsianHateCrimes',
#        'indices': [239, 259]},
#       {'text': 'StopAAPIHate', 'indices': [260, 273]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 222680234,
#      'id_str': '222680234',
#      'name': 'Jae-Ha Kim 김재하',
#      'screen_name': 'GoAwayWithJae',
#      'location': 'Chicago',
#      'description': '🇰🇷Life without kimchi is no life at all┆KDramas for life\n✍️Syndicated Culture Columnist @TribuneAgency┆Also @ChicagoTribune @TeenVogue @NYDailyNews etc.',
#      'url': 'https://t.co/FDsOMWCPX0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/FDsOMWCPX0',
#          'expanded_url': 'https://www.jaehakim.com',
#          'display_url': 'jaehakim.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 65075,
#      'friends_count': 372,
#      'listed_count': 308,
#      'created_at': 'Sat Dec 04 03:35:38 +0000 2010',
#      'favourites_count': 88613,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 36699,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '352726',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/429122145457680384/orCu3sgP_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/429122145457680384/orCu3sgP_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/222680234/1531585049',
#      'profile_link_color': 'D02B55',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '99CC33',
#      'profile_text_color': '3E4415',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 121,
#     'favorite_count': 502,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 121,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.164,
#   'max_id': 1379447501531529217,
#   'max_id_str': '1379447501531529217',
#   'next_results': '?max_id=1379443228458545163&q=%5B%27asian%27%2C%20%27asians%27%5D&lang=en&count=100&include_entities=1',
#   'query': '%5B%27asian%27%2C+%27asians%27%5D',
#   'refresh_url': '?since_id=1379447501531529217&q=%5B%27asian%27%2C%20%27asians%27%5D&lang=en&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
tweetsWithSent = []
for t in tweets['statuses']:
   text = (t['full_text'])
   ps = analyzer.polarity_scores(text)
   tweetsWithSent.append({'text':text, 'compound':ps['compound']})

# %% [markdown]
# ### Areas of no bars indicate neutral tweets

# %%
import pandas as pd
tweetdf = pd.DataFrame(tweetsWithSent)
tweetdf.plot.bar(figsize=(15,5),width=1)

# %%
tweetdf.head(50)
# Out:
#                                                  text  compound
# 0   RT @badvibesdni: finally asian racism is being...   -0.8860
# 1   RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 2   RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 3   @MelanieForEdu @RethinkSchools You mean how yo...    0.4660
# 4   RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 5   RT @DevTrehan: BREAKING: Sikh brothers Bhups a...    0.4215
# 6   RT @ejrdavid: The most prominent Asian America...    0.4900
# 7   What’s the term for people forming asian-ness ...    0.0000
# 8   RT @cmliwagdixon: Good morning to everyone exc...    0.4404
# 9   RT @thatjulieren: Blame, violence, gendered wo...   -0.8957
# 10  Asian people have issues in their own communit...   -0.9480
# 11  RT @itztimi31: Everyone, non-asians or asians,...    0.3182
# 12  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 13  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 14  RT @GoAwayWithJae: "I never heard anyone use s...    0.0000
# 15  RT @eddieliuwho: My mom tells me on the phone ...   -0.9300
# 16  RT @jokieliu: @xXxKyle667xXx Wokelords make ev...    0.7579
# 17  @Rick_Zou @politico Liberals are the most anti...   -0.5849
# 18  RT @DevTrehan: BREAKING: Sikh brothers Bhups a...    0.4215
# 19  RT @badvibesdni: finally asian racism is being...   -0.8860
# 20  @Smilelikekookie I'm asian in asia so maybe I'...    0.0000
# 21  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 22  RT @ginashiii: xinyan was never black and will...   -0.4228
# 23  @aspecpjospidesi I feel like mostly north Amer...    0.6124
# 24  @GoAwayWithJae I think as a lot of Asian belie...   -0.6249
# 25  RT @badvibesdni: finally asian racism is being...   -0.8860
# 26  @noahreservation That’s pretty good! The next ...    0.6010
# 27  @liaoshenyi @jamestwotree @albertowu the Asian...   -0.2960
# 28  RT @thedailybeast: “What I love the most—and I...    0.6908
# 29  RT @doritegrocery: A white woman stabs an Asia...   -0.5792
# 30  RT @jokieliu: @xXxKyle667xXx Wokelords make ev...    0.7579
# 31  RT @phichithamster: I literally don't understa...    0.0000
# 32  RT @TaureanReign: YouTube Removes YG's "Meet T...    0.0000
# 33  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 34  RT @GoAwayWithJae: "I never heard anyone use s...    0.0000
# 35  RT @chris_notcapn: I’m confused. Are South Asi...   -0.5043
# 36  @qingxincecilia um. by all means is mhy in the...   -0.2617
# 37  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 38  RT @eddieliuwho: My mom tells me on the phone ...   -0.9300
# 39  RT @ejrdavid: The most prominent Asian America...    0.4900
# 40  @MelanieWdwrth @BET @reghud Asians are 6% of t...   -0.1901
# 41  RT @chris_notcapn: I’m confused. Are South Asi...   -0.5043
# 42  RT @SHAQBLAC: Outside of the Asian community, ...    0.0000
# 43  RT @phichithamster: I literally don't understa...    0.0000
# 44  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 45  RT @VABVOX: Pretty sure VP Harris is the most ...    0.7960
# 46  Another black man attacks asians (with a metal...   -0.5707
# 47  RT @zoyaboi: @xinyanluvsu @GenshinImpact hey i...   -0.6310
# 48  RT @phichithamster: I literally don't understa...    0.0000
# 49  I literally don't understand what some (white ...    0.0000

# %%
tweetdf.dtypes
# Out:
# text         object
# compound    float64
# dtype: object

# %% [markdown]
# ### We tested the accuracy of sentiment detection by inputting sentences manually to the analyzer object

# %%
s1 = "I don't like asian people"
s2 = "I really like the new design of your website!"
s3 = "I’m not sure if I like the new design"
s4 = "The new design is awful!"
s5 = "They’re rapists … some, I assume, are good people"
s6 = "U got some shitty weather Illinois.... I miss texas heat"
s7 = "It’s annoying when a program does the “you sure you want to quit? thing but I’d be lying if I said it hasn’t saved my ass anumber of times"
s8 = "I have made the awful decision to stay up all night. Why? Because I’m stupid as fuck"

# %%
vs = analyzer.polarity_scores(s1)
print("{}… {}".format(s1, str(vs)))

vs = analyzer.polarity_scores(s2)
print("{}… {}".format(s2, str(vs)))

vs = analyzer.polarity_scores(s3)
print("{}… {}".format(s3, str(vs)))

vs = analyzer.polarity_scores(s4)
print("{}… {}".format(s4, str(vs)))

vs = analyzer.polarity_scores(s5)
print("{}… {}".format(s5, str(vs)))

vs = analyzer.polarity_scores(s6)
print("{}… {}".format(s6, str(vs)))

vs = analyzer.polarity_scores(s7)
print("{}… {}".format(s7, str(vs)))

vs = analyzer.polarity_scores(s8)
print("{}… {}".format(s8, str(vs)))
# Out:
# I don't like asian people… {'neg': 0.345, 'neu': 0.655, 'pos': 0.0, 'compound': -0.2755}
# I really like the new design of your website!… {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.474}
# I’m not sure if I like the new design… {'neg': 0.171, 'neu': 0.611, 'pos': 0.218, 'compound': 0.1376}
# The new design is awful!… {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.5093}
# They’re rapists … some, I assume, are good people… {'neg': 0.303, 'neu': 0.493, 'pos': 0.204, 'compound': -0.34}
# U got some shitty weather Illinois.... I miss texas heat… {'neg': 0.394, 'neu': 0.606, 'pos': 0.0, 'compound': -0.6369}
# It’s annoying when a program does the “you sure you want to quit? thing but I’d be lying if I said it hasn’t saved my ass anumber of times… {'neg': 0.275, 'neu': 0.565, 'pos': 0.16, 'compound': -0.7717}
# I have made the awful decision to stay up all night. Why? Because I’m stupid as fuck… {'neg': 0.414, 'neu': 0.586, 'pos': 0.0, 'compound': -0.872}

# %%
count = 200
query = ["asian","asians"]
tweets = twitter_api.search.tweets(q=query, count=count, 
   lang='en',tweet_mode="extended")

# %%
tweets
# Out:
# {'statuses': [{'created_at': 'Tue Apr 06 16:55:51 +0000 2021',
#    'id': 1379477968523829250,
#    'id_str': '1379477968523829250',
#    'full_text': 'RT @WFDYS: There has been an on-going rise of hate crimes and racism against Asians all over the world. We, the WFDYS, want to assert again…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WFDYS',
#       'name': 'WFDYS',
#       'id': 81941265,
#       'id_str': '81941265',
#       'indices': [3, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 22855589,
#     'id_str': '22855589',
#     'name': 'Abigail Gorman (She/Her)',
#     'screen_name': 'abigailgorman',
#     'location': '',
#     'description': 'Policy & Public Affairs manager @Signhealth. Human Rights Expert @WFDeaf_org. LGBT+ activist. Feminist. Sarcastic optimist. Views my own.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1697,
#     'friends_count': 912,
#     'listed_count': 22,
#     'created_at': 'Thu Mar 05 00:48:59 +0000 2009',
#     'favourites_count': 4555,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7401,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FF6699',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1354906179441463301/qDH9mY3B_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1354906179441463301/qDH9mY3B_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22855589/1615230360',
#     'profile_link_color': 'B40B43',
#     'profile_sidebar_border_color': 'CC3366',
#     'profile_sidebar_fill_color': 'E5507E',
#     'profile_text_color': '362720',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 00:38:47 +0000 2021',
#     'id': 1379232078231965696,
#     'id_str': '1379232078231965696',
#     'full_text': 'There has been an on-going rise of hate crimes and racism against Asians all over the world. We, the WFDYS, want to assert again that any form of hate and racism are never acceptable. We stand in solidarity with the Asian community and all Asian people. #StopAsianHate https://t.co/a0T8Ev3rq0',
#     'truncated': False,
#     'display_text_range': [0, 268],
#     'entities': {'hashtags': [{'text': 'StopAsianHate',
#        'indices': [254, 268]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1379229589705256960,
#        'id_str': '1379229589705256960',
#        'indices': [269, 292],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1379229589705256960/pu/img/E8kEDNYoXwvqBI1U.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1379229589705256960/pu/img/E8kEDNYoXwvqBI1U.jpg',
#        'url': 'https://t.co/a0T8Ev3rq0',
#        'display_url': 'pic.twitter.com/a0T8Ev3rq0',
#        'expanded_url': 'https://twitter.com/WFDYS/status/1379232078231965696/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 848, 'h': 480, 'resize': 'fit'},
#         'medium': {'w': 848, 'h': 480, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 385, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1379229589705256960,
#        'id_str': '1379229589705256960',
#        'indices': [269, 292],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1379229589705256960/pu/img/E8kEDNYoXwvqBI1U.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1379229589705256960/pu/img/E8kEDNYoXwvqBI1U.jpg',
#        'url': 'https://t.co/a0T8Ev3rq0',
#        'display_url': 'pic.twitter.com/a0T8Ev3rq0',
#        'expanded_url': 'https://twitter.com/WFDYS/status/1379232078231965696/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 848, 'h': 480, 'resize': 'fit'},
#         'medium': {'w': 848, 'h': 480, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 385, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [53, 30],
#         'duration_millis': 43733,
#         'variants': [{'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1379229589705256960/pu/pl/jjRYDMhBoVkbYoC8.m3u8?tag=12'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1379229589705256960/pu/vid/476x270/7iG-0VNamCOFN6i0.mp4?tag=12'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1379229589705256960/pu/vid/848x480/ddy0e4Qf2QLoBCWH.mp4?tag=12'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1379229589705256960/pu/vid/636x360/t5r0tPpDw1mFxMlk.mp4?tag=12'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 81941265,
#      'id_str': '81941265',
#      'name': 'WFDYS',
#      'screen_name': 'WFDYS',
#      'location': '',
#      'description': 'World Federation of the Deaf Youth Section, established in 1995, is commited in promoting human rights and equality of the Deaf Youth around the globe.',
#      'url': 'https://t.co/fvjKucU6sG',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/fvjKucU6sG',
#          'expanded_url': 'http://www.wfdys.org',
#          'display_url': 'wfdys.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4099,
#      'friends_count': 88,
#      'listed_count': 69,
#      'created_at': 'Mon Oct 12 22:09:10 +0000 2009',
#      'favourites_count': 160,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1262,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'B2DFDA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/2162516556/wfdys_logo_twitter_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2162516556/wfdys_logo_twitter_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/81941265/1583941093',
#      'profile_link_color': '93A644',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 22,
#     'favorite_count': 39,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 22,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:55:51 +0000 2021',
#    'id': 1379477968032948230,
#    'id_str': '1379477968032948230',
#    'full_text': '@jaweedkaleem @latimes " . .need for white communities to learn more about Asian American church traditions"\n\nAgree. But what about black communities? With the exception of the Atlanta shootings, have not most, if not all, of the recent well publicized horrific violent attacks on Asians been by blacks?',
#    'truncated': False,
#    'display_text_range': [23, 303],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jaweedkaleem',
#       'name': 'Jaweed Kaleem',
#       'id': 14819030,
#       'id_str': '14819030',
#       'indices': [0, 13]},
#      {'screen_name': 'latimes',
#       'name': 'Los Angeles Times',
#       'id': 16664681,
#       'id_str': '16664681',
#       'indices': [14, 22]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1379471331557666817,
#    'in_reply_to_status_id_str': '1379471331557666817',
#    'in_reply_to_user_id': 14819030,
#    'in_reply_to_user_id_str': '14819030',
#    'in_reply_to_screen_name': 'jaweedkaleem',
#    'user': {'id': 273059145,
#     'id_str': '273059145',
#     'name': 'Gary Hall',
#     'screen_name': 'GaryWHall',
#     'location': 'Los Angeles, CA',
#     'description': 'It is what it is.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 376,
#     'friends_count': 307,
#     'listed_count': 7,
#     'created_at': 'Sun Mar 27 18:59:27 +0000 2011',
#     'favourites_count': 17492,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 26118,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1289356142/gary_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289356142/gary_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/273059145/1563412070',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:55:38 +0000 2021',
#    'id': 1379477911321915399,
#    'id_str': '1379477911321915399',
#    'full_text': "@genocidefile @alphabet4726482 @chenweihua He may be American ,but he must came from China(mostly like Taiwan province)\n\nIf you look at his tweets, they are all about Anti China.\nThere are few Americans who  only pay attention to Anti-China.\n\nUnless he's a psycho,just like those Asian-hater who attacked Asians",
#    'truncated': False,
#    'display_text_range': [43, 311],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'genocidefile',
#       'name': 'ً',
#       'id': 3357321592,
#       'id_str': '3357321592',
#       'indices': [0, 13]},
#      {'screen_name': 'alphabet4726482',
#       'name': 'Bob',
#       'id': 1178065910818426880,
#       'id_str': '1178065910818426880',
#       'indices': [14, 30]},
#      {'screen_name': 'chenweihua',
#       'name': 'Chen Weihua （陈卫华）',
#       'id': 88702710,
#       'id_str': '88702710',
#       'indices': [31, 42]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1379473149687914497,
#    'in_reply_to_status_id_str': '1379473149687914497',
#    'in_reply_to_user_id': 3357321592,
#    'in_reply_to_user_id_str': '3357321592',
#    'in_reply_to_screen_name': 'genocidefile',
#    'user': {'id': 1356245338521145349,
#     'id_str': '1356245338521145349',
#     'name': '糯米',
#     'screen_name': 'CcShor',
#     'location': '',
#     'description': '满纸荒唐言，一把辛酸泪\n自从刷推，几乎不看书了，罪过罪过',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 164,
#     'friends_count': 143,
#     'listed_count': 3,
#     'created_at': 'Mon Feb 01 14:17:53 +0000 2021',
#     'favourites_count': 6923,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 4991,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1356245682428944385/C-C4EQJD_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1356245682428944385/C-C4EQJD_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:55:29 +0000 2021',
#    'id': 1379477873384431623,
#    'id_str': '1379477873384431623',
#    'full_text': "@Garilamb @ginashiii @Afro_Gamers it's not that they don't want them to be Black Asian it's just that it's not stated in the game at all that she is black, Dark skinned asians can still exist without being black ro from black culture",
#    'truncated': False,
#    'display_text_range': [34, 233],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Garilamb',
#       'name': 'm',
#       'id': 1323111681090818050,
#       'id_str': '1323111681090818050',
#       'indices': [0, 9]},
#      {'screen_name': 'ginashiii',
#       'name': 'xest',
#       'id': 2801174206,
#       'id_str': '2801174206',
#       'indices': [10, 20]},
#      {'screen_name': 'Afro_Gamers',
#       'name': 'AfroGamers',
#       'id': 1330590692704460801,
#       'id_str': '1330590692704460801',
#       'indices': [21, 33]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1379473612290334722,
#    'in_reply_to_status_id_str': '1379473612290334722',
#    'in_reply_to_user_id': 1323111681090818050,
#    'in_reply_to_user_id_str': '1323111681090818050',
#    'in_reply_to_screen_name': 'Garilamb',
#    'user': {'id': 1360312115769319426,
#     'id_str': '1360312115769319426',
#     'name': 'camy alt',
#     'screen_name': 'camy_alt',
#     'location': '(he/them)',
#     'description': 'ok so one piece content',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1,
#     'friends_count': 2,
#     'listed_count': 0,
#     'created_at': 'Fri Feb 12 19:38:13 +0000 2021',
#     'favourites_count': 3,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1376898754503118849/RQDaB-v7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1376898754503118849/RQDaB-v7_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:55:15 +0000 2021',
#    'id': 1379477815293177863,
#    'id_str': '1379477815293177863',
#    'full_text': 'RT @ginashiii: xinyan was never black and will NEVER BE BLACK.... she’s a dark skinned asian from liyue. it’s kinda upsetting seeing so man…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ginashiii',
#       'name': 'xest',
#       'id': 2801174206,
#       'id_str': '2801174206',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1053174508385820673,
#     'id_str': '1053174508385820673',
#     'name': '𝓟𝓻𝓸𝓾𝓵𝔁 || Modules making me cry 🙃',
#     'screen_name': 'FgoTrash',
#     'location': '',
#     'description': "Xiao you're next 👀\nPFP by @univ_rs",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 15,
#     'friends_count': 2530,
#     'listed_count': 0,
#     'created_at': 'Fri Oct 19 06:42:24 +0000 2018',
#     'favourites_count': 41027,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 721,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1353230723172372481/nKqUZFKE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353230723172372481/nKqUZFKE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053174508385820673/1595241581',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 14:15:10 +0000 2021',
#     'id': 1379437528919334917,
#     'id_str': '1379437528919334917',
#     'full_text': 'xinyan was never black and will NEVER BE BLACK.... she’s a dark skinned asian from liyue. it’s kinda upsetting seeing so many people forgetting or not caring that dark skinned asians exist. it’s very racist too. #boycottgenshinimpact https://t.co/dAYrvZfy6l',
#     'truncated': False,
#     'display_text_range': [0, 233],
#     'entities': {'hashtags': [{'text': 'boycottgenshinimpact',
#        'indices': [212, 233]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1379437517796212736,
#        'id_str': '1379437517796212736',
#        'indices': [234, 257],
#        'media_url': 'http://pbs.twimg.com/media/EyS_HSYXAAAsNew.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EyS_HSYXAAAsNew.jpg',
#        'url': 'https://t.co/dAYrvZfy6l',
#        'display_url': 'pic.twitter.com/dAYrvZfy6l',
#        'expanded_url': 'https://twitter.com/ginashiii/status/1379437528919334917/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1379437517796212736,
#        'id_str': '1379437517796212736',
#        'indices': [234, 257],
#        'media_url': 'http://pbs.twimg.com/media/EyS_HSYXAAAsNew.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EyS_HSYXAAAsNew.jpg',
#        'url': 'https://t.co/dAYrvZfy6l',
#        'display_url': 'pic.twitter.com/dAYrvZfy6l',
#        'expanded_url': 'https://twitter.com/ginashiii/status/1379437528919334917/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2801174206,
#      'id_str': '2801174206',
#      'name': 'xest',
#      'screen_name': 'ginashiii',
#      'location': 'Canada',
#      'description': 'archive acc',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1,
#      'friends_count': 270,
#      'listed_count': 1,
#      'created_at': 'Fri Oct 03 01:24:35 +0000 2014',
#      'favourites_count': 2985,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1072,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1377494210077716481/ozRD5SB1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1377494210077716481/ozRD5SB1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2801174206/1613360976',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 97,
#     'favorite_count': 827,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 97,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:54:52 +0000 2021',
#    'id': 1379477719143055361,
#    'id_str': '1379477719143055361',
#    'full_text': 'RT @chris_notcapn: I’m confused. Are South Asians not considered Asian? Please make it make sense.',
#    'truncated': False,
#    'display_text_range': [0, 98],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chris_notcapn',
#       'name': 'i’m unwilling',
#       'id': 1139189085241794562,
#       'id_str': '1139189085241794562',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1161528810610798593,
#     'id_str': '1161528810610798593',
#     'name': 'Shouting In The Void ✊🏽',
#     'screen_name': 'bats_johnny',
#     'location': 'Nashville, TN',
#     'description': "I promise I'm a real person,  but we all have to start somewhere, right?\n\nBlack lives are just as significant as others.\n\nhe / him\n\nRetweets ≠ endorsements.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 178,
#     'friends_count': 1626,
#     'listed_count': 2,
#     'created_at': 'Wed Aug 14 06:43:43 +0000 2019',
#     'favourites_count': 50210,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 25425,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1184563447385731072/cGm9p-Ql_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1184563447385731072/cGm9p-Ql_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1161528810610798593/1579124728',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 02:36:18 +0000 2021',
#     'id': 1379261655444520961,
#     'id_str': '1379261655444520961',
#     'full_text': 'I’m confused. Are South Asians not considered Asian? Please make it make sense.',
#     'truncated': False,
#     'display_text_range': [0, 79],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1139189085241794562,
#      'id_str': '1139189085241794562',
#      'name': 'i’m unwilling',
#      'screen_name': 'chris_notcapn',
#      'location': '',
#      'description': '✊🏽 🏳️\u200d🌈',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 22399,
#      'friends_count': 791,
#      'listed_count': 52,
#      'created_at': 'Thu Jun 13 15:13:37 +0000 2019',
#      'favourites_count': 6291,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 19948,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1371298295767838728/JnjInoLt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1371298295767838728/JnjInoLt_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1139189085241794562/1560885616',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 38,
#     'favorite_count': 561,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 38,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:54:43 +0000 2021',
#    'id': 1379477682983890952,
#    'id_str': '1379477682983890952',
#    'full_text': 'RT @GoAwayWithJae: "I never heard anyone use slurs against Asians..." -- non-Asian person\n\nThis is a common reply from people to downplay w…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GoAwayWithJae',
#       'name': 'Jae-Ha Kim 김재하',
#       'id': 222680234,
#       'id_str': '222680234',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 874871777096237060,
#     'id_str': '874871777096237060',
#     'name': '𝕯.𝖗𝖑𝖓 💜ᴮᴱ⁷',
#     'screen_name': 'Alej_twt',
#     'location': 'B.C., México 🇲🇽',
#     'description': 'ARMY 💜 ot7 / 27 y.o. /// GOT7 + Day6 + MonstaX / ----\nElla - She/her',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 398,
#     'friends_count': 770,
#     'listed_count': 2,
#     'created_at': 'Wed Jun 14 06:11:00 +0000 2017',
#     'favourites_count': 32239,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 33379,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1236902712463077376/Tw50KCm9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1236902712463077376/Tw50KCm9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/874871777096237060/1543912979',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 13:49:52 +0000 2021',
#     'id': 1379431164058820615,
#     'id_str': '1379431164058820615',
#     'full_text': '"I never heard anyone use slurs against Asians..." -- non-Asian person\n\nThis is a common reply from people to downplay what\'s going on. Why would you hear it if you\'re not Asian? People don\'t target non-Asian people for anti-Asian hate.🤓\n\n#StopAsianHateCrimes #StopAAPIHate',
#     'truncated': False,
#     'display_text_range': [0, 273],
#     'entities': {'hashtags': [{'text': 'StopAsianHateCrimes',
#        'indices': [239, 259]},
#       {'text': 'StopAAPIHate', 'indices': [260, 273]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 222680234,
#      'id_str': '222680234',
#      'name': 'Jae-Ha Kim 김재하',
#      'screen_name': 'GoAwayWithJae',
#      'location': 'Chicago',
#      'description': '🇰🇷Life without kimchi is no life at all┆KDramas for life\n✍️Syndicated Culture Columnist @TribuneAgency┆Also @ChicagoTribune @TeenVogue @NYDailyNews etc.',
#      'url': 'https://t.co/FDsOMWCPX0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/FDsOMWCPX0',
#          'expanded_url': 'https://www.jaehakim.com',
#          'display_url': 'jaehakim.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 65075,
#      'friends_count': 372,
#      'listed_count': 308,
#      'created_at': 'Sat Dec 04 03:35:38 +0000 2010',
#      'favourites_count': 88615,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 36698,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '352726',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/429122145457680384/orCu3sgP_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/429122145457680384/orCu3sgP_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/222680234/1531585049',
#      'profile_link_color': 'D02B55',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '99CC33',
#      'profile_text_color': '3E4415',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 184,
#     'favorite_count': 777,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 184,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:54:06 +0000 2021',
#    'id': 1379477527027183619,
#    'id_str': '1379477527027183619',
#    'full_text': 'RT @Toxic_Strike: #boycottgenshinimpact white girls being racist by trying to fight racism. Dark skin asians exist. And it makes sense for…',
#    'truncated': False,
#    'display_text_range': [0, 139],
#    'entities': {'hashtags': [{'text': 'boycottgenshinimpact',
#       'indices': [18, 39]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Toxic_Strike',
#       'name': 'Artemis',
#       'id': 1135961316139700224,
#       'id_str': '1135961316139700224',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2295386702,
#     'id_str': '2295386702',
#     'name': 'Royger Short',
#     'screen_name': 'roygerdodger',
#     'location': 'Jamestown, North Carolina',
#     'description': "I'll write a bio later.",
#     'url': 'https://t.co/DWblXNEoIu',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DWblXNEoIu',
#         'expanded_url': 'https://www.amazon.com/hz/wishlist/ls/U172HAFG8DKZ?ref_=wl_share',
#         'display_url': 'amazon.com/hz/wishlist/ls…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1605,
#     'friends_count': 4990,
#     'listed_count': 73,
#     'created_at': 'Fri Jan 17 03:15:01 +0000 2014',
#     'favourites_count': 4322,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 298,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1317307473318039553/_hKi5GGa_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317307473318039553/_hKi5GGa_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2295386702/1602905670',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 15:02:19 +0000 2021',
#     'id': 1379449396207755265,
#     'id_str': '1379449396207755265',
#     'full_text': '#boycottgenshinimpact white girls being racist by trying to fight racism. Dark skin asians exist. And it makes sense for an Asian dev to design Asian characters. Race isn’t just black and white. Not all asians are the same skin tone. Good lord. https://t.co/KcgJmgy7XE',
#     'truncated': False,
#     'display_text_range': [0, 244],
#     'entities': {'hashtags': [{'text': 'boycottgenshinimpact',
#        'indices': [0, 21]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1379449392101482496,
#        'id_str': '1379449392101482496',
#        'indices': [245, 268],
#        'media_url': 'http://pbs.twimg.com/media/EyTJ6dnWYAAvGyH.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EyTJ6dnWYAAvGyH.jpg',
#        'url': 'https://t.co/KcgJmgy7XE',
#        'display_url': 'pic.twitter.com/KcgJmgy7XE',
#        'expanded_url': 'https://twitter.com/Toxic_Strike/status/1379449396207755265/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1379449392101482496,
#        'id_str': '1379449392101482496',
#        'indices': [245, 268],
#        'media_url': 'http://pbs.twimg.com/media/EyTJ6dnWYAAvGyH.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EyTJ6dnWYAAvGyH.jpg',
#        'url': 'https://t.co/KcgJmgy7XE',
#        'display_url': 'pic.twitter.com/KcgJmgy7XE',
#        'expanded_url': 'https://twitter.com/Toxic_Strike/status/1379449396207755265/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1135961316139700224,
#      'id_str': '1135961316139700224',
#      'name': 'Artemis',
#      'screen_name': 'Toxic_Strike',
#      'location': '',
#      'description': 'she/her idfk anymore',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11,
#      'friends_count': 134,
#      'listed_count': 0,
#      'created_at': 'Tue Jun 04 17:27:37 +0000 2019',
#      'favourites_count': 37,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 359,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1379459995134275584/g-m7wjx3_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1379459995134275584/g-m7wjx3_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 31,
#     'favorite_count': 260,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 31,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:53:57 +0000 2021',
#    'id': 1379477487948816384,
#    'id_str': '1379477487948816384',
#    'full_text': '@chriswiltrout1 @tommcgillis @mikeisapinecone he literally said that she’s south asian...plus south asians don’t have a specific look ppl tell me i look hispanic all the time but i’m south asian',
#    'truncated': False,
#    'display_text_range': [46, 194],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chriswiltrout1',
#       'name': 'Chris💜',
#       'id': 738811444632924161,
#       'id_str': '738811444632924161',
#       'indices': [0, 15]},
#      {'screen_name': 'tommcgillis',
#       'name': 'Tom McGillis',
#       'id': 94247357,
#       'id_str': '94247357',
#       'indices': [16, 28]},
#      {'screen_name': 'mikeisapinecone',
#       'name': 'michael',
#       'id': 3303333532,
#       'id_str': '3303333532',
#       'indices': [29, 45]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1036790934183325697,
#    'in_reply_to_status_id_str': '1036790934183325697',
#    'in_reply_to_user_id': 738811444632924161,
#    'in_reply_to_user_id_str': '738811444632924161',
#    'in_reply_to_screen_name': 'chriswiltrout1',
#    'user': {'id': 1226719436184412160,
#     'id_str': '1226719436184412160',
#     'name': 'Amanda',
#     'screen_name': 'Amanda65329004',
#     'location': '',
#     'description': 'i want the album out lana',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 115,
#     'listed_count': 0,
#     'created_at': 'Mon Feb 10 04:08:07 +0000 2020',
#     'favourites_count': 57,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1307030871824838657/zN-6gJwL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1307030871824838657/zN-6gJwL_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:53:21 +0000 2021',
#    'id': 1379477339998806018,
#    'id_str': '1379477339998806018',
#    'full_text': "RT @Wiseronenow: @SenWhitehouse @Barryhallphd And, I have to believe his wife's Asian corporate donors are pretty pissed that neither he no…",
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Wiseronenow',
#       'name': 'Wiseronenow~~Life is a birdsong.',
#       'id': 18005208,
#       'id_str': '18005208',
#       'indices': [3, 15]},
# ...
#        'indices': [94, 99]}],
#      'urls': [{'url': 'https://t.co/XNDZF6TS7b',
#        'expanded_url': 'https://www.skysports.com/football/news/11095/12266232/championship-history-to-be-made-by-british-south-asian-referees-bhups-and-sunny-singh-gill',
#        'display_url': 'skysports.com/football/news/…',
#        'indices': [224, 247]}],
#      'media': [{'id': 1379379673566752773,
#        'id_str': '1379379673566752773',
#        'indices': [272, 295],
#        'media_url': 'http://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'url': 'https://t.co/zywGpV9EAn',
#        'display_url': 'pic.twitter.com/zywGpV9EAn',
#        'expanded_url': 'https://twitter.com/DevTrehan/status/1379415969416814596/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1379379673566752773,
#        'id_str': '1379379673566752773',
#        'indices': [272, 295],
#        'media_url': 'http://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EySKgT1XMAUJFf_.jpg',
#        'url': 'https://t.co/zywGpV9EAn',
#        'display_url': 'pic.twitter.com/zywGpV9EAn',
#        'expanded_url': 'https://twitter.com/DevTrehan/status/1379415969416814596/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 747043795,
#      'id_str': '747043795',
#      'name': 'Dev Trehan',
#      'screen_name': 'DevTrehan',
#      'location': 'London - Liverpool - Las Vegas',
#      'description': 'Changing the landscape @SkySportsNews\nArchitect: #HiddenFigures Digital: #MyIcon\nCo-world record holder \nEx @talkSPORT @bbc5live @EasternEye \nAmbassador of Quan',
#      'url': 'http://t.co/lv9Lm1CFza',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/lv9Lm1CFza',
#          'expanded_url': 'http://www.facebook.com/devtrehan46',
#          'display_url': 'facebook.com/devtrehan46',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1970,
#      'friends_count': 2283,
#      'listed_count': 42,
#      'created_at': 'Thu Aug 09 11:16:58 +0000 2012',
#      'favourites_count': 2819,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10119,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/915639503011926016/NmM-rRQF_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/915639503011926016/NmM-rRQF_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/747043795/1507140037',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 80,
#     'favorite_count': 313,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 80,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:27:45 +0000 2021',
#    'id': 1379470895559901186,
#    'id_str': '1379470895559901186',
#    'full_text': "@jahaha_0 I'm west asian? this is something I've discussed at length with other west asians + south asians + southeast asians and come to a conclusion because of it. i guarantee u i care about real issues, but i also want to see my culture respected when put in media",
#    'truncated': False,
#    'display_text_range': [10, 267],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jahaha_0',
#       'name': 'jahaha',
#       'id': 1147790645609713664,
#       'id_str': '1147790645609713664',
#       'indices': [0, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1379469711277051907,
#    'in_reply_to_status_id_str': '1379469711277051907',
#    'in_reply_to_user_id': 1147790645609713664,
#    'in_reply_to_user_id_str': '1147790645609713664',
#    'in_reply_to_screen_name': 'jahaha_0',
#    'user': {'id': 1367118854833504262,
#     'id_str': '1367118854833504262',
#     'name': 'briar',
#     'screen_name': 'hamcakeharlot',
#     'location': '',
#     'description': "#AKIRA: honey, i'm home! • it/he • @catboytartagIia girlboss /r",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 95,
#     'friends_count': 89,
#     'listed_count': 3,
#     'created_at': 'Wed Mar 03 14:25:19 +0000 2021',
#     'favourites_count': 595,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2028,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1375551635934605312/fiWrGvh2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1375551635934605312/fiWrGvh2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1367118854833504262/1616792040',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Tue Apr 06 16:27:39 +0000 2021',
#    'id': 1379470870742233088,
#    'id_str': '1379470870742233088',
#    'full_text': 'RT @WSYourSpace: NEW PODCAST! Racial Equality - Episode 5 - Asian Hate - Young people from the West Sussex Youth Cabinet have a conversatio…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WSYourSpace',
#       'name': 'WSYourSpace',
#       'id': 258727704,
#       'id_str': '258727704',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1268129322948276225,
#     'id_str': '1268129322948276225',
#     'name': 'Daisy Watson',
#     'screen_name': 'daisy_watsonYC',
#     'location': '',
#     'description': 'Chair of the West Sussex Youth Cabinet | Mental Health Rep for West Sussex | @trusselltrust advocate | all views my own :)',
#     'url': 'https://t.co/ITia0F4z8G',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ITia0F4z8G',
#         'expanded_url': 'https://linktr.ee/daisywatsonwsyc',
#         'display_url': 'linktr.ee/daisywatsonwsyc',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 132,
#     'friends_count': 332,
#     'listed_count': 2,
#     'created_at': 'Wed Jun 03 10:36:13 +0000 2020',
#     'favourites_count': 914,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 339,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1362030444276031489/eQKRrvcv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1362030444276031489/eQKRrvcv_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1268129322948276225/1613648847',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Apr 06 15:45:05 +0000 2021',
#     'id': 1379460159131553796,
#     'id_str': '1379460159131553796',
#     'full_text': 'NEW PODCAST! Racial Equality - Episode 5 - Asian Hate - Young people from the West Sussex Youth Cabinet have a conversation about hate towards Asians. You can listen to this one and others from out blog site: https://t.co/gDo7XK02kn https://t.co/oO9IBiiorM',
#     'truncated': False,
#     'display_text_range': [0, 232],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gDo7XK02kn',
#        'expanded_url': 'https://yourspacewestsussex.me/2021/02/23/racial-equality-podcasts/',
#        'display_url': 'yourspacewestsussex.me/2021/02/23/rac…',
#        'indices': [209, 232]}],
#      'media': [{'id': 1379460158129111043,
#        'id_str': '1379460158129111043',
#        'indices': [233, 256],
#        'media_url': 'http://pbs.twimg.com/media/EyTTtIMXAAMyswA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EyTTtIMXAAMyswA.jpg',
#        'url': 'https://t.co/oO9IBiiorM',
#        'display_url': 'pic.twitter.com/oO9IBiiorM',
#        'expanded_url': 'https://twitter.com/WSYourSpace/status/1379460159131553796/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 768, 'h': 768, 'resize': 'fit'},
#         'large': {'w': 768, 'h': 768, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1379460158129111043,
#        'id_str': '1379460158129111043',
#        'indices': [233, 256],
#        'media_url': 'http://pbs.twimg.com/media/EyTTtIMXAAMyswA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EyTTtIMXAAMyswA.jpg',
#        'url': 'https://t.co/oO9IBiiorM',
#        'display_url': 'pic.twitter.com/oO9IBiiorM',
#        'expanded_url': 'https://twitter.com/WSYourSpace/status/1379460159131553796/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 768, 'h': 768, 'resize': 'fit'},
#         'large': {'w': 768, 'h': 768, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 258727704,
#      'id_str': '258727704',
#      'name': 'WSYourSpace',
#      'screen_name': 'WSYourSpace',
#      'location': 'West Sussex',
#      'description': 'Helping to build a better future for young people in West Sussex.',
#      'url': 'https://t.co/xKekG588Dm',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/xKekG588Dm',
#          'expanded_url': 'https://yourspacewestsussex.me/2021/01/20/political-engagement-webinars/',
#          'display_url': 'yourspacewestsussex.me/2021/01/20/pol…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1229,
#      'friends_count': 1203,
#      'listed_count': 37,
#      'created_at': 'Mon Feb 28 10:42:53 +0000 2011',
#      'favourites_count': 1180,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6510,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '022330',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1190182679200833536/9Lls0v_Y_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190182679200833536/9Lls0v_Y_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/258727704/1612370074',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'A8C7F7',
#      'profile_sidebar_fill_color': 'C0DFEC',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.127,
#   'max_id': 1379477968523829250,
#   'max_id_str': '1379477968523829250',
#   'next_results': '?max_id=1379470870742233087&q=%5B%27asian%27%2C%20%27asians%27%5D&lang=en&count=100&include_entities=1',
#   'query': '%5B%27asian%27%2C+%27asians%27%5D',
#   'refresh_url': '?since_id=1379477968523829250&q=%5B%27asian%27%2C%20%27asians%27%5D&lang=en&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
tweetsWithSentLoc = []
for t in tweets['statuses']:
   text = (t['full_text'])
   location = (t['user']['location'])
   ps = analyzer.polarity_scores(text)
   tweetsWithSentLoc.append({'text':text, 'compound_sentiment_scores':ps['compound'], 'location':location})

# %%
pd.DataFrame(tweetsWithSentLoc).head(50)
# Out:
#                                                  text  \
# 0   RT @WFDYS: There has been an on-going rise of ...
# 1   @jaweedkaleem @latimes " . .need for white com...
# 2   @genocidefile @alphabet4726482 @chenweihua He ...
# 3   @Garilamb @ginashiii @Afro_Gamers it's not tha...
# 4   RT @ginashiii: xinyan was never black and will...
# 5   RT @chris_notcapn: I’m confused. Are South Asi...
# 6   RT @GoAwayWithJae: "I never heard anyone use s...
# 7   RT @Toxic_Strike: #boycottgenshinimpact white ...
# 8   @chriswiltrout1 @tommcgillis @mikeisapinecone ...
# 9   RT @Wiseronenow: @SenWhitehouse @Barryhallphd ...
# 10  RT @dilfdnf: - saying that east asians or blac...
# 11  RT @ginashiii: xinyan was never black and will...
# 12  @Dot21280827 @Fiona_s_done @jvkt14 @Chaotic_Me...
# 13  @susanchang100 @TheBlueRose15 @DionLimTV @eart...
# 14  @tariqnasheed This must be a lie and all of ou...
# 15  RT @ginashiii: xinyan was never black and will...
# 16  RT @cgtnamerica: Why are hate crimes against A...
# 17  RT @ginashiii: xinyan was never black and will...
# 18  Hypocrisy: When Asians speak out against white...
# 19  RT @ejrdavid: The most prominent Asian America...
# 20  RT @activeasian: The Asian community is outrag...
# 21  RT @ejrdavid: The most prominent Asian America...
# 22  RT @ejrdavid: The most prominent Asian America...
# 23  RT @christiansager: I grew up in Singapore and...
# 24  RT @GoAwayWithJae: "I never heard anyone use s...
# 25  RT @GoAwayWithJae: "I never heard anyone use s...
# 26  RT @terrygtnguyen: this piece primarily focuse...
# 27  RT @ginashiii: xinyan was never black and will...
# 28  RT @dilfdnf: - saying that east asians or blac...
# 29  @geesubay Cute &amp; horror got us beaten up A...
# 30  RT @Toxic_Strike: #boycottgenshinimpact white ...
# 31  @JohnnyFan69 kpop stans trying to erase idols’...
# 32  RT @minjinlee11: For every person who says tha...
# 33  RT @dilfdnf: - saying that east asians or blac...
# 34  RT @ginashiii: xinyan was never black and will...
# 35  @gottajinx We get that. Also racism can happen...
# 36  RT @MrAndyNgo: You might have seen viral tweet...
# 37  @idktommyinnit @updatesinnit I'm not Asian, an...
# 38  BLACK NY DOORMAN FIRED...FOR NOT RUNNING OUTSI...
# 39  RT @GoAwayWithJae: "I never heard anyone use s...
# 40  RT @cgtnamerica: Why are hate crimes against A...
# 41  Black Asians you are not a thing according to ...
# 42  RT @WFDYS: There has been an on-going rise of ...
# 43  RT @DevTrehan: BREAKING: Sikh brothers Bhups a...
# 44  RT @dilfdnf: - saying that east asians or blac...
# 45  @AFRODIYKE For those artists? Why didn’t op de...
# 46  RT @DevTrehan: BREAKING: Sikh brothers Bhups a...
# 47  RT @DevTrehan: BREAKING: Sikh brothers Bhups a...
# 48  RT @GoAwayWithJae: "I never heard anyone use s...
# 49  @DevTrehan @SkySportsNews @SkySports @sunnygil...
#
#     compound_sentiment_scores                       location
# 0                     -0.8176
# 1                     -0.9356                Los Angeles, CA
# 2                     -0.2617
# 3                     -0.0572                      (he/them)
# 4                     -0.4228
# 5                     -0.5043                  Nashville, TN
# 6                      0.0000                B.C., México 🇲🇽
# 7                     -0.8934      Jamestown, North Carolina
# 8                      0.0000
# 9                     -0.2500
# 10                    -0.3818               she/her  e.asian
# 11                    -0.4228
# 12                     0.2924                    your dreams
# 13                    -0.8981                    SF Bay Area
# 14                    -0.8807                   Brooklyn, NY
# 15                    -0.4228
# 16                    -0.9601              Bangkok, Thailand
# 17                    -0.4228
# 18                    -0.3869
# 19                     0.4900  iPhone: 34.147064,-118.002876
# 20                    -0.8979          YangVille, USA, World
# 21                     0.4900                     Dallas, TX
# 22                     0.4900
# 23                    -0.3182             /̶𝚞̶𝚜̶𝚛̶/̶𝚋̶𝚒̶𝚗̶/̶
# 24                     0.0000      Pansexual☆Mexican☆she/her
# 25                     0.0000
# 26                     0.5499                 Washington, DC
# 27                    -0.4228
# 28                    -0.3818
# 29                    -0.7319                 sadly, Florida
# 30                    -0.8934                she/her/herse;f
# 31                    -0.5588       she/her + minor + latine
# 32                     0.6486          YangVille, USA, World
# 33                    -0.3818
# 34                    -0.4228
# 35                    -0.2023                        𝙷𝚎/𝚑𝚒𝚖
# 36                    -0.6597
# 37                     0.3736
# 38                    -0.9220
# 39                     0.0000
# 40                    -0.9601
# 41                     0.0000                     SHE|HER|21
# 42                    -0.8176          Vancouver, BC, Canada
# 43                     0.4215
# 44                    -0.3818
# 45                     0.9054
# 46                     0.4215    Dubai, United Arab Emirates
# 47                     0.4215               Somwhere in East
# 48                     0.0000     7yrsMore🥨soon to be 7 CEOs
# 49                     0.8586
